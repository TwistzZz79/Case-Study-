# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv("Case study data set.csv")

# %%
df.head()
# Out:
#   Season       Supplier Original Order-No.     Order-No. Order Date  \
# 0   SS24  Eagle Textile       PO01OM003594  PO01OM003594   13.07.23
# 1   SS24  Eagle Textile       PO01OM003594  PO01OM003594   13.07.23
# 2   SS24  Eagle Textile       PO01OM003594  PO01OM003594   13.07.23
# 3   SS24  Eagle Textile       PO01OM003594  PO01OM003594   13.07.23
# 4   SS24  Eagle Textile       PO01OM003594  PO01OM003594   13.07.23
#
#   PO Category    Article Style  Color Code Color Description  ...   Warehouse  \
# 0        Bulk  344.00816   344       816.0    Black | Shadow  ...  LUX-KN-STK
# 1        Bulk  354.00825   354       825.0    Black | Shadow  ...  LUX-KN-STK
# 2        Bulk  364.00836   364       836.0    Black | Shadow  ...  LUX-KN-STK
# 3        Bulk  354.00826   354       826.0     White | Ivory  ...  LUX-KN-STK
# 4        Bulk  345.00822   345       822.0     White | Ivory  ...  LUX-KN-STK
#
#   Destination/Country Requested XF date Fty. 1st Conf. Ready Date  \
# 0          Luxembourg          22.09.23                  22.09.23
# 1          Luxembourg          22.09.23                  22.09.23
# 2          Luxembourg          22.09.23                  22.09.23
# 3          Luxembourg          22.09.23                  22.09.23
# 4          Luxembourg          22.09.23                  22.09.23
#
#   Current Ex-Fty. Date Delay reason Qty. ord.  Qty. Cfmd.  \
# 0             22.09.23          NaN     600.0         600
# 1             22.09.23          NaN     700.0         700
# 2             22.09.23          NaN    1050.0        1050
# 3             22.09.23          NaN     700.0         700
# 4             22.09.23          NaN     600.0         600
#
#    Current Price/Piece Mode of Transport
# 0                 3.28             Truck
# 1                  3.6             Truck
# 2                 4.28             Truck
# 3                  3.6             Truck
# 4                 3.28             Truck
#
# [5 rows x 21 columns]

# %%
df.columns=df.columns.str.lower().str.replace(' ','_')
df.columns=df.columns.str.lower().str.replace('-','_')
df.columns=df.columns.str.lower().str.replace('.','')
# Out:
# C:\Users\sondu\AppData\Local\Temp\ipykernel_13252\140332619.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.lower().str.replace('.','')

# %%
df.head()
# Out:
#   season       supplier original_order_no      order_no order_date  \
# 0   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 1   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 2   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 3   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 4   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
#
#   po_category    article style  color_code color_description  ...   warehouse  \
# 0        Bulk  344.00816   344       816.0    Black | Shadow  ...  LUX-KN-STK
# 1        Bulk  354.00825   354       825.0    Black | Shadow  ...  LUX-KN-STK
# 2        Bulk  364.00836   364       836.0    Black | Shadow  ...  LUX-KN-STK
# 3        Bulk  354.00826   354       826.0     White | Ivory  ...  LUX-KN-STK
# 4        Bulk  345.00822   345       822.0     White | Ivory  ...  LUX-KN-STK
#
#   destination/country requested_xf_date fty_1st_conf_ready_date  \
# 0          Luxembourg          22.09.23                22.09.23
# 1          Luxembourg          22.09.23                22.09.23
# 2          Luxembourg          22.09.23                22.09.23
# 3          Luxembourg          22.09.23                22.09.23
# 4          Luxembourg          22.09.23                22.09.23
#
#   current_ex_fty_date delay_reason qty_ord  qty_cfmd  current_price/piece  \
# 0            22.09.23          NaN   600.0       600                 3.28
# 1            22.09.23          NaN   700.0       700                  3.6
# 2            22.09.23          NaN  1050.0      1050                 4.28
# 3            22.09.23          NaN   700.0       700                  3.6
# 4            22.09.23          NaN   600.0       600                 3.28
#
#   mode_of_transport
# 0             Truck
# 1             Truck
# 2             Truck
# 3             Truck
# 4             Truck
#
# [5 rows x 21 columns]

# %%
print(df.dtypes)
# Out:
# season                      object
# supplier                    object
# original_order_no           object
# order_no                    object
# order_date                  object
# po_category                 object
# article                     object
# style                       object
# color_code                 float64
# color_description           object
# model_name                  object
# warehouse                   object
# destination/country         object
# requested_xf_date           object
# fty_1st_conf_ready_date     object
# current_ex_fty_date         object
# delay_reason                object
# qty_ord                    float64
# qty_cfmd                     int64
# current_price/piece         object
# mode_of_transport           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6315 entries, 0 to 6314
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   season                   6314 non-null   object
#  1   supplier                 6314 non-null   object
#  2   original_order_no        6314 non-null   object
#  3   order_no                 6314 non-null   object
#  4   order_date               6314 non-null   object
#  5   po_category              6314 non-null   object
#  6   article                  6314 non-null   object
#  7   style                    6314 non-null   object
#  8   color_code               5077 non-null   float64
#  9   color_description        6314 non-null   object
#  10  model_name               6314 non-null   object
#  11  warehouse                6314 non-null   object
#  12  destination/country      6314 non-null   object
#  13  requested_xf_date        6314 non-null   object
#  14  fty_1st_conf_ready_date  6314 non-null   object
#  15  current_ex_fty_date      6314 non-null   object
#  16  delay_reason             3677 non-null   object
#  17  qty_ord                  6314 non-null   float64
#  18  qty_cfmd                 6315 non-null   int64
#  19  current_price/piece      6315 non-null   object
#  20  mode_of_transport        6314 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#          color_code      qty_ord      qty_cfmd
# count   5077.000000  6314.000000  6.315000e+03
# mean    1019.788064   270.364903  5.243834e+02
# std      592.542033   448.194911  2.192429e+04
# min       57.000000     1.000000  1.000000e+00
# 25%      831.000000    50.000000  4.600000e+01
# 50%      881.000000   120.000000  1.000000e+02
# 75%     1191.000000   300.000000  2.600000e+02
# max    10211.000000  6900.000000  1.742171e+06

# %%
#check for missing data
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
    #delay and color code
# Out:
# season - 0.00015835312747426763%
# supplier - 0.00015835312747426763%
# original_order_no - 0.00015835312747426763%
# order_no - 0.00015835312747426763%
# order_date - 0.00015835312747426763%
# po_category - 0.00015835312747426763%
# article - 0.00015835312747426763%
# style - 0.00015835312747426763%
# color_code - 0.19604117181314332%
# color_description - 0.00015835312747426763%
# model_name - 0.00015835312747426763%
# warehouse - 0.00015835312747426763%
# destination/country - 0.00015835312747426763%
# requested_xf_date - 0.00015835312747426763%
# fty_1st_conf_ready_date - 0.00015835312747426763%
# current_ex_fty_date - 0.00015835312747426763%
# delay_reason - 0.41773555027711795%
# qty_ord - 0.00015835312747426763%
# qty_cfmd - 0.0%
# current_price/piece - 0.0%
# mode_of_transport - 0.00015835312747426763%

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# season
# ['SS24' 'FW22' 'SS23' 'FW23' 'SS22']
# 5
#
# supplier
# ['Eagle Textile' 'OVERCLOTHES S.p.A.' 'STONETEX MANUFACTURING SA'
#  'RIM Tekstil A.S.' 'Gunther Bohr GMBH']
# 5
#
# original_order_no
# ['PO01OM003594' 'PO010035681' 'PO010035684' 'PO010035682' 'PO010035677']
# 922
#
# order_no
# ['PO01OM003594' 'PO010035681' 'PO010035684' 'PO010035682' 'PO010035677']
# 961
#
# order_date
# ['13.07.23' '25.02.22' '24.02.22' '29.07.22' '25.08.22']
# 76
#
# po_category
# ['Bulk' 'Special Ed' 'Media' nan]
# 3
#
# article
# ['344.00816' '354.00825' '364.00836' '354.00826' '345.00822']
# 354
#
# style
# ['344' '354' '364' '345' '355']
# 171
#
# color_code
# [816. 825. 836. 826. 822.]
# 239
#
# color_description
# ['Black | Shadow' 'White | Ivory' 'Black' 'Comet | Flame'
#  'Zest | Stratosphere']
# 114
#
# model_name
# ['Performance Low Sock' 'Performance Mid Sock' 'Performance High Sock'
#  'Logo Sock 3-Pack' 'All-Day Sock']
# 64
#
# warehouse
# ['LUX-KN-STK' 'IC JP TOY' 'IC CN SHA' 'IC AU MEL' 'IC HK HKG']
# 16
#
# destination/country
# ['Luxembourg' 'Japan' 'China' 'Australia' 'Hong Kong']
# 10
#
# requested_xf_date
# ['22.09.23' '20.06.22' '17.04.22' '27.06.22' '03.10.22']
# 66
#
# fty_1st_conf_ready_date
# ['22.09.23' '20.06.22' '15.05.22' '27.06.22' '03.10.22']
# 95
#
# current_ex_fty_date
# ['22.09.23' '05.08.22' '09.09.22' '03.04.23' '15.02.23']
# 132
#
# delay_reason
# [nan 'Trims delay' 'Fabric Delay' 'Capacity constraint']
# 3
#
# qty_ord
# [ 600.  700. 1050. 1000.  100.]
# 580
#
# qty_cfmd
# [ 600  700 1050 1000  100]
# 632
#
# current_price/piece
# ['3.28' '3.6' '4.28' '5.08' '4.26']
# 156
#
# mode_of_transport
# ['Truck' 'Sea' 'Air' nan]
# 3

# %% [markdown]
# ## Transforming Data

# %%
df['delay'] = df['delay_reason'].notna()

# %%
df.head()
# Out:
#   season       supplier original_order_no      order_no order_date  \
# 0   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 1   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 2   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 3   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 4   SS24  Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
#
#   po_category    article style  color_code color_description  ...  \
# 0        Bulk  344.00816   344       816.0    Black | Shadow  ...
# 1        Bulk  354.00825   354       825.0    Black | Shadow  ...
# 2        Bulk  364.00836   364       836.0    Black | Shadow  ...
# 3        Bulk  354.00826   354       826.0     White | Ivory  ...
# 4        Bulk  345.00822   345       822.0     White | Ivory  ...
#
#   destination/country requested_xf_date fty_1st_conf_ready_date  \
# 0          Luxembourg          22.09.23                22.09.23
# 1          Luxembourg          22.09.23                22.09.23
# 2          Luxembourg          22.09.23                22.09.23
# 3          Luxembourg          22.09.23                22.09.23
# 4          Luxembourg          22.09.23                22.09.23
#
#   current_ex_fty_date delay_reason qty_ord qty_cfmd  current_price/piece  \
# 0            22.09.23          NaN   600.0      600                 3.28
# 1            22.09.23          NaN   700.0      700                  3.6
# 2            22.09.23          NaN  1050.0     1050                 4.28
# 3            22.09.23          NaN   700.0      700                  3.6
# 4            22.09.23          NaN   600.0      600                 3.28
#
#    mode_of_transport  delay
# 0              Truck  False
# 1              Truck  False
# 2              Truck  False
# 3              Truck  False
# 4              Truck  False
#
# [5 rows x 22 columns]

# %%
df.delay==(df.delay=='False').astype(int)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6310    True
# 6311    True
# 6312    True
# 6313    True
# 6314    True
# Name: delay, Length: 6315, dtype: bool

# %%
print(df.iloc[63]['delay'])
print(df.iloc[1]['delay'])
# Out:
# True
# False

# %%
df.color_code
# Out:
# 0         816.0
# 1         825.0
# 2         836.0
# 3         826.0
# 4         822.0
#          ...
# 6310    10211.0
# 6311      219.0
# 6312      222.0
# 6313      218.0
# 6314        NaN
# Name: color_code, Length: 6315, dtype: float64

# %%
#df.delay_reason=pd.to_numeric(df.delay_reason,errors='coerce')
#df.delay_reason=df.delay_reason.fillna(0)

#df.color_code=pd.to_numeric(df.color_code,errors='coerce')
#df.color_code=df.color_code.fillna(0)

# %%
#for col in df.columns:
 #   df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#for col in df.columns:
  #  df[col] = df[col].fillna(0)

# %%
df.isnull().sum()
# Out:
# season                        1
# supplier                      1
# original_order_no             1
# order_no                      1
# order_date                    1
# po_category                   1
# article                       1
# style                         1
# color_code                 1238
# color_description             1
# model_name                    1
# warehouse                     1
# destination/country           1
# requested_xf_date             1
# fty_1st_conf_ready_date       1
# current_ex_fty_date           1
# delay_reason               2638
# qty_ord                       1
# qty_cfmd                      0
# current_price/piece           0
# mode_of_transport             1
# delay                         0
# dtype: int64

# %%
df
# Out:
#      season           supplier original_order_no      order_no order_date  \
# 0      SS24      Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 1      SS24      Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 2      SS24      Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 3      SS24      Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# 4      SS24      Eagle Textile      PO01OM003594  PO01OM003594   13.07.23
# ...     ...                ...               ...           ...        ...
# 6310   FW22  Gunther Bohr GMBH       PO010013524   PO010013524   06.04.22
# 6311   FW22  Gunther Bohr GMBH       PO010013524   PO010013524   06.04.22
# 6312   FW22  Gunther Bohr GMBH       PO010013524   PO010013524   06.04.22
# 6313   FW22  Gunther Bohr GMBH       PO010013524   PO010013524   06.04.22
# 6314    NaN                NaN               NaN           NaN        NaN
#
#      po_category    article style  color_code color_description  ...  \
# 0           Bulk  344.00816   344       816.0    Black | Shadow  ...
# 1           Bulk  354.00825   354       825.0    Black | Shadow  ...
# 2           Bulk  364.00836   364       836.0    Black | Shadow  ...
# 3           Bulk  354.00826   354       826.0     White | Ivory  ...
# 4           Bulk  345.00822   345       822.0     White | Ivory  ...
# ...          ...        ...   ...         ...               ...  ...
# 6310        Bulk  311.10211   311     10211.0             Black  ...
# 6311        Bulk  311.00219   311       219.0              Navy  ...
# 6312        Bulk  311.00222   311       222.0             White  ...
# 6313        Bulk  311.00218   311       218.0             Lunar  ...
# 6314         NaN        NaN   NaN         NaN               NaN  ...
#
#      destination/country requested_xf_date fty_1st_conf_ready_date  \
# 0             Luxembourg          22.09.23                22.09.23
# 1             Luxembourg          22.09.23                22.09.23
# 2             Luxembourg          22.09.23                22.09.23
# 3             Luxembourg          22.09.23                22.09.23
# 4             Luxembourg          22.09.23                22.09.23
# ...                  ...               ...                     ...
# 6310           Hong Kong          28.06.22                14.06.22
# 6311           Hong Kong          28.06.22                14.06.22
# 6312           Hong Kong          28.06.22                14.06.22
# 6313           Hong Kong          28.06.22                14.06.22
# 6314                 NaN               NaN                     NaN
#
#      current_ex_fty_date delay_reason qty_ord qty_cfmd  current_price/piece  \
# 0               22.09.23          NaN   600.0      600                 3.28
# 1               22.09.23          NaN   700.0      700                  3.6
# 2               22.09.23          NaN  1050.0     1050                 4.28
# 3               22.09.23          NaN   700.0      700                  3.6
# 4               22.09.23          NaN   600.0      600                 3.28
# ...                  ...          ...     ...      ...                  ...
# 6310            14.06.22          NaN   130.0      130                  9.9
# 6311            14.06.22          NaN    65.0       65                  9.9
# 6312            14.06.22          NaN    45.0       45                  9.9
# 6313            14.06.22          NaN    80.0       80                  9.9
# 6314                 NaN          NaN     NaN  1742171           220'358.48
#
#       mode_of_transport  delay
# 0                 Truck  False
# 1                 Truck  False
# 2                 Truck  False
# 3                 Truck  False
# 4                 Truck  False
# ...                 ...    ...
# 6310                Air  False
# 6311                Air  False
# 6312                Air  False
# 6313                Air  False
# 6314                NaN  False
#
# [6315 rows x 22 columns]

# %%
#for col in df.columns:
  #  df = df.dropna(subset=[col])

# %%
df.isnull().sum()
# Out:
# season                        1
# supplier                      1
# original_order_no             1
# order_no                      1
# order_date                    1
# po_category                   1
# article                       1
# style                         1
# color_code                 1238
# color_description             1
# model_name                    1
# warehouse                     1
# destination/country           1
# requested_xf_date             1
# fty_1st_conf_ready_date       1
# current_ex_fty_date           1
# delay_reason               2638
# qty_ord                       1
# qty_cfmd                      0
# current_price/piece           0
# mode_of_transport             1
# delay                         0
# dtype: int64

# %%
df
# Out:
#      season           supplier original_order_no      order_no order_date  \
# 61     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 62     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 63     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 64     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 65     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# ...     ...                ...               ...           ...        ...
# 6305   FW22  Gunther Bohr GMBH      PO01OM000694  PO01OM000694   13.12.21
# 6306   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6307   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6308   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6309   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
#
#      po_category    article style  color_code color_description  ...  \
# 61          Bulk  364.00836   364       836.0    Black | Shadow  ...
# 62          Bulk  344.00818   344       818.0   Twilight | Navy  ...
# 63          Bulk  344.00818   344       818.0   Twilight | Navy  ...
# 64          Bulk  345.00821   345       821.0    Black | Shadow  ...
# 65          Bulk  345.00821   345       821.0    Black | Shadow  ...
# ...          ...        ...   ...         ...               ...  ...
# 6305        Bulk  311.10211   311     10211.0             Black  ...
# 6306        Bulk  311.00218   311       218.0             Lunar  ...
# 6307        Bulk  311.10211   311     10211.0             Black  ...
# 6308        Bulk  311.00219   311       219.0              Navy  ...
# 6309        Bulk  311.00222   311       222.0             White  ...
#
#      destination/country requested_xf_date fty_1st_conf_ready_date  \
# 61                 Japan          17.04.22                15.05.22
# 62                 Japan          17.04.22                15.05.22
# 63                 Japan          17.04.22                15.05.22
# 64                 Japan          17.04.22                15.05.22
# 65                 Japan          17.04.22                15.05.22
# ...                  ...               ...                     ...
# 6305         Switzerland          28.06.22                22.06.22
# 6306              Canada          28.06.22                07.08.22
# 6307              Canada          28.06.22                07.08.22
# 6308              Canada          28.06.22                07.08.22
# 6309              Canada          28.06.22                07.08.22
#
#      current_ex_fty_date         delay_reason qty_ord qty_cfmd  \
# 61              09.09.22          Trims delay    95.0       95
# 62              09.09.22          Trims delay   100.0       11
# 63              09.09.22          Trims delay   100.0       89
# 64              09.09.22          Trims delay   100.0       50
# 65              09.09.22          Trims delay   100.0       50
# ...                  ...                  ...     ...      ...
# 6305            15.08.22  Capacity constraint   100.0      100
# 6306            25.07.22  Capacity constraint   100.0      100
# 6307            25.07.22  Capacity constraint   300.0      300
# 6308            25.07.22  Capacity constraint   500.0      500
# 6309            25.07.22  Capacity constraint   230.0      230
#
#       current_price/piece  mode_of_transport delay
# 61                   4.26                Sea  True
# 62                   3.28                Sea  True
# 63                   3.28                Sea  True
# 64                   3.28                Sea  True
# 65                   3.28                Sea  True
# ...                   ...                ...   ...
# 6305                  9.9              Truck  True
# 6306                  9.9                Air  True
# 6307                  9.9                Air  True
# 6308                  9.9                Air  True
# 6309                  9.9                Air  True
#
# [2887 rows x 22 columns]

# %% [markdown]
# ## EDA

# %%
delay_count_by_season=df.groupby('season')['delay'].sum()

# %%
print(delay_count_by_season)
# Out:
# season
# FW22    1200
# FW23     584
# SS22     758
# SS23     962
# SS24     173
# Name: delay, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.bar(delay_count_by_season.index, delay_count_by_season.values, color='skyblue')
plt.title('Delay Count by Season')
plt.xlabel('Season')
plt.ylabel('Delay Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
delay_count_by_supplier=df.groupby('supplier')['delay'].sum()

# %%
print(delay_count_by_supplier)
# Out:
# supplier
# Eagle Textile                1373
# Gunther Bohr GMBH              92
# OVERCLOTHES S.p.A.           1212
# RIM Tekstil A.S.              579
# STONETEX MANUFACTURING SA     421
# Name: delay, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.bar(delay_count_by_supplier.index, delay_count_by_supplier.values, color='skyblue')
plt.title('Delay Count by Supplier')
plt.xlabel('Suplier')
plt.ylabel('Delay Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
delay_count_by_season_supplier = df.groupby(['season', 'supplier'])['delay'].sum()

# %%
delay_count_by_season_supplier
# Out:
# season  supplier
# FW22    Eagle Textile                501
#         Gunther Bohr GMBH             28
#         OVERCLOTHES S.p.A.           650
#         RIM Tekstil A.S.              21
# FW23    Eagle Textile                 28
#         Gunther Bohr GMBH             18
#         OVERCLOTHES S.p.A.            13
#         RIM Tekstil A.S.             425
#         STONETEX MANUFACTURING SA    100
# SS22    Eagle Textile                538
#         OVERCLOTHES S.p.A.           220
#         RIM Tekstil A.S.               0
# SS23    Eagle Textile                306
#         Gunther Bohr GMBH             32
#         OVERCLOTHES S.p.A.           317
#         RIM Tekstil A.S.               1
#         STONETEX MANUFACTURING SA    306
# SS24    Eagle Textile                  0
#         Gunther Bohr GMBH             14
#         OVERCLOTHES S.p.A.            12
#         RIM Tekstil A.S.             132
#         STONETEX MANUFACTURING SA     15
# Name: delay, dtype: int64

# %%
df.groupby(['mode_of_transport'])['delay'].sum()
# Out:
# mode_of_transport
# Air       953
# Sea      1600
# Truck    1124
# Name: delay, dtype: int64

# %%
df.groupby(['mode_of_transport', 'supplier'])['delay'].sum()
# Out:
# mode_of_transport  supplier
# Air                Eagle Textile                398
#                    Gunther Bohr GMBH             23
#                    OVERCLOTHES S.p.A.           214
#                    RIM Tekstil A.S.              12
#                    STONETEX MANUFACTURING SA    306
# Sea                Eagle Textile                592
#                    Gunther Bohr GMBH             38
#                    OVERCLOTHES S.p.A.           582
#                    RIM Tekstil A.S.             346
#                    STONETEX MANUFACTURING SA     42
# Truck              Eagle Textile                383
#                    Gunther Bohr GMBH             31
#                    OVERCLOTHES S.p.A.           416
#                    RIM Tekstil A.S.             221
#                    STONETEX MANUFACTURING SA     73
# Name: delay, dtype: int64

# %%
df.groupby(['mode_of_transport', 'season'])['delay'].sum()
# Out:
# mode_of_transport  season
# Air                FW22      180
#                    FW23       19
#                    SS22      451
#                    SS23      303
# Sea                FW22      660
#                    FW23      317
#                    SS22       53
#                    SS23      460
#                    SS24      110
# Truck              FW22      360
#                    FW23      248
#                    SS22      254
#                    SS23      199
#                    SS24       63
# Name: delay, dtype: int64

# %%
transport_delay=df.groupby(['mode_of_transport', 'season','supplier'])['delay'].sum()

# %%
transport_delay_df = transport_delay.unstack(level=[0, 1])

# Plotting
for transport_mode, data in transport_delay_df.items():
    plt.figure(figsize=(8, 5))
    data.plot(kind='bar', color='skyblue')
    plt.title(f'Total Delay by Supplier and Season - {transport_mode[0]}')
    plt.xlabel('(Supplier, Season)')
    plt.ylabel('Total Delay')
    plt.legend(title='Season', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
filtered_df=df[df['delay_reason'].notna()]

# %%
filtered_df
# Out:
#      season           supplier original_order_no      order_no order_date  \
# 61     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 62     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 63     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 64     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# 65     FW22      Eagle Textile       PO010012172   PO010012172   24.02.22
# ...     ...                ...               ...           ...        ...
# 6305   FW22  Gunther Bohr GMBH      PO01OM000694  PO01OM000694   13.12.21
# 6306   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6307   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6308   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
# 6309   FW22  Gunther Bohr GMBH       PO010008863   PO010008863   13.12.21
#
#      po_category    article style  color_code color_description  ...  \
# 61          Bulk  364.00836   364       836.0    Black | Shadow  ...
# 62          Bulk  344.00818   344       818.0   Twilight | Navy  ...
# 63          Bulk  344.00818   344       818.0   Twilight | Navy  ...
# 64          Bulk  345.00821   345       821.0    Black | Shadow  ...
# 65          Bulk  345.00821   345       821.0    Black | Shadow  ...
# ...          ...        ...   ...         ...               ...  ...
# 6305        Bulk  311.10211   311     10211.0             Black  ...
# 6306        Bulk  311.00218   311       218.0             Lunar  ...
# 6307        Bulk  311.10211   311     10211.0             Black  ...
# 6308        Bulk  311.00219   311       219.0              Navy  ...
# 6309        Bulk  311.00222   311       222.0             White  ...
#
#      destination/country requested_xf_date fty_1st_conf_ready_date  \
# 61                 Japan          17.04.22                15.05.22
# 62                 Japan          17.04.22                15.05.22
# 63                 Japan          17.04.22                15.05.22
# 64                 Japan          17.04.22                15.05.22
# 65                 Japan          17.04.22                15.05.22
# ...                  ...               ...                     ...
# 6305         Switzerland          28.06.22                22.06.22
# 6306              Canada          28.06.22                07.08.22
# 6307              Canada          28.06.22                07.08.22
# 6308              Canada          28.06.22                07.08.22
# 6309              Canada          28.06.22                07.08.22
#
#      current_ex_fty_date         delay_reason qty_ord qty_cfmd  \
# 61              09.09.22          Trims delay    95.0       95
# 62              09.09.22          Trims delay   100.0       11
# 63              09.09.22          Trims delay   100.0       89
# 64              09.09.22          Trims delay   100.0       50
# 65              09.09.22          Trims delay   100.0       50
# ...                  ...                  ...     ...      ...
# 6305            15.08.22  Capacity constraint   100.0      100
# 6306            25.07.22  Capacity constraint   100.0      100
# 6307            25.07.22  Capacity constraint   300.0      300
# 6308            25.07.22  Capacity constraint   500.0      500
# 6309            25.07.22  Capacity constraint   230.0      230
#
#       current_price/piece  mode_of_transport delay
# 61                   4.26                Sea  True
# 62                   3.28                Sea  True
# 63                   3.28                Sea  True
# 64                   3.28                Sea  True
# 65                   3.28                Sea  True
# ...                   ...                ...   ...
# 6305                  9.9              Truck  True
# 6306                  9.9                Air  True
# 6307                  9.9                Air  True
# 6308                  9.9                Air  True
# 6309                  9.9                Air  True
#
# [3677 rows x 22 columns]

# %%
supplier_reason=df.groupby(['delay_reason', 'supplier'])['delay'].sum()

# %%
supplier_reason
# Out:
# delay_reason         supplier
# Capacity constraint  Eagle Textile                882
#                      Gunther Bohr GMBH             75
#                      OVERCLOTHES S.p.A.           992
#                      RIM Tekstil A.S.             534
#                      STONETEX MANUFACTURING SA    238
# Fabric Delay         Eagle Textile                 41
#                      OVERCLOTHES S.p.A.            58
#                      STONETEX MANUFACTURING SA     15
# Trims delay          Eagle Textile                450
#                      Gunther Bohr GMBH             17
#                      OVERCLOTHES S.p.A.           162
#                      RIM Tekstil A.S.              45
#                      STONETEX MANUFACTURING SA    168
# Name: delay, dtype: int64

# %%
supplier_delay_reason=df.groupby(['delay_reason', 'supplier',"season"])['delay'].sum()

# %%
supplier_delay_reason
# Out:
# delay_reason         supplier                   season
# Capacity constraint  Eagle Textile              FW22      302
#                                                 FW23       28
#                                                 SS22      246
#                                                 SS23      306
#                      Gunther Bohr GMBH          FW22       21
#                                                 FW23        9
#                                                 SS23       31
#                                                 SS24       14
#                      OVERCLOTHES S.p.A.         FW22      530
#                                                 FW23        8
#                                                 SS22      125
#                                                 SS23      317
#                                                 SS24       12
#                      RIM Tekstil A.S.           FW22       21
#                                                 FW23      399
#                                                 SS23        1
#                                                 SS24      113
#                      STONETEX MANUFACTURING SA  FW23       94
#                                                 SS23      129
#                                                 SS24       15
# Fabric Delay         Eagle Textile              FW22       20
#                                                 SS22       21
#                      OVERCLOTHES S.p.A.         SS22       58
#                      STONETEX MANUFACTURING SA  SS23       15
# Trims delay          Eagle Textile              FW22      179
#                                                 SS22      271
#                      Gunther Bohr GMBH          FW22        7
#                                                 FW23        9
#                                                 SS23        1
#                      OVERCLOTHES S.p.A.         FW22      120
#                                                 FW23        5
#                                                 SS22       37
#                      RIM Tekstil A.S.           FW23       26
#                                                 SS24       19
#                      STONETEX MANUFACTURING SA  FW23        6
#                                                 SS23      162
# Name: delay, dtype: int64

# %%
# Iterate over each delay reason and create a separate plot
for delay_reason, data in supplier_delay_reason_df.items():
    plt.figure(figsize=(8, 5))
    data.plot(kind='bar', color='skyblue')
    plt.title(f'Total Delay by Supplier and Season - {delay_reason}')
    plt.xlabel('(Supplier, Season)')
    plt.ylabel('Total Delay')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
supplier_delay_reason_df = supplier_delay_reason.unstack(level=[0, 2])

supplier_delay_reason_df.plot(kind='bar', figsize=(10, 6))
plt.title('Total Delay by Supplier and Season')
plt.xlabel('(Supplier, Season)')
plt.ylabel('Total Delay')
plt.legend(title='Delay Reason', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
average_qty_ord=df['qty_ord'].mean()

# %%
print(average_qty_ord)
# Out:
# 270.36490338929366

# %%
print(df[df['qty_ord']<270]['delay'].sum())
# Out:
# 2602

# %%
print(df[df['qty_ord']>270]['delay'].sum())
# Out:
# 1059

# %%
print(df[df['delay'] > 0]['qty_ord'].mean())
# Out:
# 275.35028555887953

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# season
# ['SS24' 'FW22' 'SS23' 'FW23' 'SS22']
# 5
#
# supplier
# ['Eagle Textile' 'OVERCLOTHES S.p.A.' 'STONETEX MANUFACTURING SA'
#  'RIM Tekstil A.S.' 'Gunther Bohr GMBH']
# 5
#
# original_order_no
# ['PO01OM003594' 'PO010035681' 'PO010035684' 'PO010035682' 'PO010035677']
# 922
#
# order_no
# ['PO01OM003594' 'PO010035681' 'PO010035684' 'PO010035682' 'PO010035677']
# 961
#
# order_date
# ['13.07.23' '25.02.22' '24.02.22' '29.07.22' '25.08.22']
# 76
#
# po_category
# ['Bulk' 'Special Ed' 'Media']
# 3
#
# article
# ['344.00816' '354.00825' '364.00836' '354.00826' '345.00822']
# 354
#
# style
# ['344' '354' '364' '345' '355']
# 171
#
# color_code
# [816. 825. 836. 826. 822.]
# 240
#
# color_description
# ['Black | Shadow' 'White | Ivory' 'Black' 'Comet | Flame'
#  'Zest | Stratosphere']
# 114
#
# model_name
# ['Performance Low Sock' 'Performance Mid Sock' 'Performance High Sock'
#  'Logo Sock 3-Pack' 'All-Day Sock']
# 64
#
# warehouse
# ['LUX-KN-STK' 'IC JP TOY' 'IC CN SHA' 'IC AU MEL' 'IC HK HKG']
# 16
#
# destination/country
# ['Luxembourg' 'Japan' 'China' 'Australia' 'Hong Kong']
# 10
#
# requested_xf_date
# ['22.09.23' '20.06.22' '17.04.22' '27.06.22' '03.10.22']
# 66
#
# fty_1st_conf_ready_date
# ['22.09.23' '20.06.22' '15.05.22' '27.06.22' '03.10.22']
# 95
#
# current_ex_fty_date
# ['22.09.23' '05.08.22' '09.09.22' '03.04.23' '15.02.23']
# 132
#
# delay_reason
# [0.]
# 1
#
# qty_ord
# [ 600.  700. 1050. 1000.  100.]
# 580
#
# qty_cfmd
# [ 600  700 1050 1000  100]
# 631
#
# current_price/piece
# ['3.28' '3.6' '4.28' '5.08' '4.26']
# 155
#
# mode_of_transport
# ['Truck' 'Sea' 'Air']
# 3
#
# delay
# [False  True]
# 2

# %% [markdown]
# ## Logistic Classification

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (3789, 1263, 1263)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.delay.values
y_val = df_val.delay.values
y_test = df_test.delay.values

del df_train['delay']
del df_val['delay']
del df_test['delay']

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train.delay.value_counts(normalize=True)
# Out:
# True     0.581354
# False    0.418646
# Name: delay, dtype: float64

# %%
global_delay_rate=df_full_train.delay.mean()
round(global_delay_rate,2)
# Out:
# 0.58

# %%
df_full_train.dtypes
# Out:
# season                      object
# supplier                    object
# original_order_no           object
# order_no                    object
# order_date                  object
# po_category                 object
# article                     object
# style                       object
# color_code                 float64
# color_description           object
# model_name                  object
# warehouse                   object
# destination/country         object
# requested_xf_date           object
# fty_1st_conf_ready_date     object
# current_ex_fty_date         object
# delay_reason                object
# qty_ord                    float64
# qty_cfmd                     int64
# current_price/piece         object
# mode_of_transport           object
# delay                         bool
# dtype: object

# %%
categories=['season','supplier','po_category','destination/country','qty_ord','warehouse','mode_of_transport']

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse=False)

train_dict = df_train[categories].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categories].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 2
#       1 model = LogisticRegression(max_iter=1000)
# ----> 2 model.fit(X_train, y_train)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# File D:\Anaconda\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
y_pred = model.predict_proba(X_val)[:, 1]

# %%
delay_decision=y_pred>=0.5

# %%
df_pred=pd.DataFrame()
df_pred['probability']=y_pred
df_pred['prediction']=delay_decision.astype(int)
df_pred['actual']=y_val

# %%
df_pred['correct']=df_pred.prediction==df_pred.actual

# %%
dicts_full_train=df_full_train[categories].to_dict(orient='records')

# %%
dicts_full_train[:3]

# %%
dv=DictVectorizer(sparse=False)

# %%
X_full_train=dv.fit_transform(dicts_full_train)
y_full_train=df_full_train.delay.values

# %%
model = LogisticRegression(max_iter=1000).fit(X_full_train,y_full_train)

# %%
dicts_test=df_test[categories].to_dict(orient='records')
X_test=dv.fit_transform(dicts_test)

# %%
print(X_test.shape)

# %%
y_pred=model.predict_proba(X_test)[:,1]

# %%
delay_decision=(y_pred>=0.5)

# %%
supplier=dicts_test[30]

# %%
X_small=dv.transform([supplier])

# %%
X_small.shape

# %%
model.predict_proba(X_small)

# %%
y_test[30]
